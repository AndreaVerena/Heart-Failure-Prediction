# %% [markdown]
# # Heart Failure prediction

# %% [markdown]
# ## Introduction
# The aim of this document is to purpose a solution to the heart failure prediction problem, using Machine Learning tools. The data consists in thirteen clinical features, twelve of them corresponds to possible predictors, and the last one is the target, this is, death event or no death event. The data can be found at UCI repository: https://archive.ics.uci.edu/ml/datasets/Heart+failure+clinical+records
#
# The description of the clinical features are:
# - age: age of the patient (years)
# - anaemia: decrease of red blood cells or hemoglobin (boolean)
# - high blood pressure: if the patient has hypertension (boolean)
# - creatinine phosphokinase (CPK): level of the CPK enzyme in the blood (mcg/L)
# - diabetes: if the patient has diabetes (boolean)
# - ejection fraction: percentage of blood leaving the heart at each contraction (percentage)
# - platelets: platelets in the blood (kiloplatelets/mL)
# - sex: woman or man (binary)
# - serum creatinine: level of serum creatinine in the blood (mg/dL)
# - serum sodium: level of serum sodium in the blood (mEq/L)
# - smoking: if the patient smokes or not (boolean)
# - time: follow-up period (days)
# - [target] death event: if the patient deceased during the follow-up period (boolean)
#
# For more information, please check Table 1, Table 2, and Table 3 of the following paper:
#
# Davide Chicco, Giuseppe Jurman: "Machine learning can predict survival of patients with heart failure from serum creatinine and ejection fraction alone". BMC Medical Informatics and Decision Making 20, 16 (2020).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import seaborn as sns
import matplotlib.patches as mpatches
import warnings
from scipy.stats import ks_2samp
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Load data

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/00519/heart_failure_clinical_records_dataset.csv')
print(data.info())
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB
# ...

# %%
binary_variables = []
continuous_variables = []
for col in data.columns[:-1]:
    if data[col].nunique() == 2:
        binary_variables.append(col)
    else:
        continuous_variables.append(col)

# %%
binary_variables, continuous_variables
# Out:
# (['anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking'],
#  ['age',
#   'creatinine_phosphokinase',
#   'ejection_fraction',
#   'platelets',
#   'serum_creatinine',
#   'serum_sodium',
#   'time'])

# %% [markdown]
# ## Explotatory Analysis
# ### Continuous variables
# #### Pairgrid plot by Death events

# %%
g = sns.pairplot(data[continuous_variables+['DEATH_EVENT']], hue="DEATH_EVENT")
g.map_offdiag(sns.scatterplot)
g.add_legend();

# %% [markdown]
# The figure above gives information about the relationship between each pair of continuous variables, and also about the relationship between each predictor and the target value "Death event".
#
# Overall, the scatter plots in all cases do not show a clear patter, for instance, no lineal shapes are shown. This anticipates weak Pearson correlations between prediction variables, however, it is recommended to calculate Pearson coefficient in order to verify what is seen at naked eye.
#
# It can be clearly seen that the distribution of each predictor is different between death event data and no death event data. The more difference between death and no death event data in the distribution of a variable, the better predictor that variable will be. A closer look of the plot diagonal is shown below.

# %%
def plot_contiuous_var(variable):
    fig, ax = plt.subplots(1,2, figsize=(14,4))
    fig.suptitle(variable.replace('_',' ').capitalize()+' distribution by death event')
    sns.histplot(data=data, x=variable, hue='DEATH_EVENT', bins=15, kde=True, ax=ax[0], legend=False)
    ax[0].set_title('Frecuency')
    sns.distplot(data[data.DEATH_EVENT==0][variable], bins=15, kde='hist', ax=ax[1])
    sns.distplot(data[data.DEATH_EVENT==1][variable], bins=15, kde='hist', ax=ax[1])
    ax[1].set_title('Normalized by group')
    plt.figlegend( labels=['Death event','No death event'], loc = 'lower center', ncol=2, labelspacing=0. );

# %% [markdown]
# #### Age

# %%
plot_contiuous_var('age')

# %% [markdown]
# #### Creatinine phosphokinase

# %%
plot_contiuous_var('creatinine_phosphokinase')

# %% [markdown]
# #### Ejection Fraction

# %%
plot_contiuous_var('ejection_fraction')

# %% [markdown]
# #### Platelets

# %%
plot_contiuous_var('platelets')

# %% [markdown]
# #### Serum creatinine

# %%
plot_contiuous_var('serum_creatinine')

# %% [markdown]
# #### Serum sodium

# %%
plot_contiuous_var('serum_sodium')

# %% [markdown]
# #### Time

# %%
plot_contiuous_var('time')

# %% [markdown]
# To sum up, there are evident differences between death event and no death event distribution in the following variables:
# * Ejection Fraction
# * Age
# * Time
# * Serum creatinine
# * Serum sodium
#
# On the other hand, Platelets, Creatinine phosphokinase and Serum sodium do not show a big difference between death/no death event distributions.
# To check this, not only by eye, also statistically, Kolmogorov-Smirnov test can be applied as follows.
#
# #### K-S test

# %%
for var in continuous_variables:
    statistic, p_value = ks_2samp(data.loc[data.DEATH_EVENT==0, var], data.loc[data.DEATH_EVENT==1, var])
    print('{} \nStatistic: {}\t p-value: {}\n'.format(var.capitalize().replace('_',' '), statistic, p_value))
# Out:
# Age
# Statistic: 0.22567733990147784	 p-value: 0.002087643655087401
#
# Creatinine phosphokinase
# Statistic: 0.10047208538587848	 p-value: 0.48687838045213694
#
# Ejection fraction
# Statistic: 0.32435344827586204	 p-value: 1.3600946602299047e-06
#
# Platelets
# Statistic: 0.10729679802955665	 p-value: 0.4050465848360226
#
# Serum creatinine
# Statistic: 0.3508312807881773	 p-value: 1.192478126244012e-07
#
# Serum sodium
# Statistic: 0.24876847290640394	 p-value: 0.00047963176249798956
#
# Time
# Statistic: 0.5922105911330049	 p-value: 0.0

# %% [markdown]
# The null hypothesis in Kolmogorov-Smirnov test is that the distributions of both samples are the same. The lower p-value, the greater the statistical evidence to reject the null hypothesis. In this case, p-value is compared with 0.05 value, therefore, if p-value is lower than 0.05, the distributions between death and no death event are different.
#
# According to the Kolmogorov-Smirnov test results, the continuous variables that shows different distributions between death and no death events are:
# * Time
# * Serum Creatinine
# * Ejection Fraction
# * Serum Sodium
# * Age

# %% [markdown]
# ### Categorical variables

# %%
def plot_categorical_variable(feature, condition=' condition'):
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
    plt.subplot(1, 2, 2)
    total = data.groupby(feature)[['DEATH_EVENT']].count().reset_index()
    death = data[data['DEATH_EVENT']==1].groupby(feature)[['DEATH_EVENT']].count().reset_index()
    death['DEATH_EVENT'] = [i / j * 100 for i,j in zip(death['DEATH_EVENT'], total['DEATH_EVENT'])]
    total['DEATH_EVENT'] = [i / j * 100 for i,j in zip(total['DEATH_EVENT'], total['DEATH_EVENT'])]
    bar1 = sns.barplot(x=str(feature), y="DEATH_EVENT", data=total, color='#3c8ecf')
    n = death['DEATH_EVENT']/(total['DEATH_EVENT'])*100
    counter_=0
    for p in bar1.patches:
        width = p.get_width()
        x, y = p.get_xy() 
        bar1.annotate(f'{n[counter_]:.2f}%', (x + width/2, y+n[counter_]/2), ha='center')
        counter_+=1
    bar2 = sns.barplot(x=str(feature), y="DEATH_EVENT", data=death, color='#ea5c3f')
    counter_=0
    for p in bar2.patches:
        width = p.get_width()
        x, y = p.get_xy() 
        if counter_ <=1:
            bar2.annotate(f'{100-n[counter_]:.2f}%', (x + width/2, (100 - n[counter_])/2+n[counter_]), ha='center')
            counter_+=1
    top_bar = mpatches.Patch(color='#3c8ecf', label='No death event')
    bottom_bar = mpatches.Patch(color='#ea5c3f', label='Death event')
    plt.legend(handles=[top_bar, bottom_bar])
    plt.ylabel('Percentage')
    plt.xlabel(feature.capitalize().replace('_',' '))
    plt.xticks([0,1], ['No','Yes'])
    if feature == 'sex':
        plt.xticks([0,1], ['Woman','Man'])
    plt.title('Proportion of death events by '+feature.capitalize().replace('_',' ')+condition);

    plt.subplot(1, 2, 1)
    total = data.groupby(feature)[['DEATH_EVENT']].count().reset_index()
    death = data[data['DEATH_EVENT']==1].groupby(feature)[['DEATH_EVENT']].count().reset_index()
    bar1 = sns.barplot(x=str(feature), y="DEATH_EVENT", data=total, color='#3c8ecf')
    n = death['DEATH_EVENT']
    counter_=0
    for p in bar1.patches:
        width = p.get_width()
        x, y = p.get_xy() 
        bar1.annotate(f'{n[counter_]:.0f}', (x + width/2, y+n[counter_]/2), ha='center')
        counter_+=1
    bar2 = sns.barplot(x=str(feature), y="DEATH_EVENT", data=death, color='#ea5c3f')
    counter_=0
    for p in bar2.patches:
        width = p.get_width()
        x, y = p.get_xy() 
        if counter_ <=1:
            t = total.loc[counter_,'DEATH_EVENT']
            bar2.annotate(f'{t-n[counter_]:.0f}', (x + width/2, (t - n[counter_])/2+n[counter_]), ha='center')
            counter_+=1
    top_bar = mpatches.Patch(color='#3c8ecf', label='No death event')
    bottom_bar = mpatches.Patch(color='#ea5c3f', label='Death event')
    plt.legend(handles=[top_bar, bottom_bar])
    plt.ylabel('Frecuency')
    plt.xlabel(feature.capitalize().replace('_',' '))
    plt.xticks([0,1], ['No','Yes'])
    if feature == 'sex':
        plt.xticks([0,1], ['Woman','Man'])
    plt.title('Count of death events by '+feature.capitalize().replace('_',' ')+condition)
plt.show()

# %% [markdown]
# #### Anaemia

# %%
plot_categorical_variable('anaemia')

# %% [markdown]
# #### Diabetes

# %%
plot_categorical_variable('diabetes')

# %% [markdown]
# #### High blood pressure

# %%
plot_categorical_variable('high_blood_pressure')

# %% [markdown]
# #### Sex

# %%
plot_categorical_variable('sex','')

# %% [markdown]
# #### Smoking

# %%
plot_categorical_variable('smoking','')

# %% [markdown]
# It can be clearly seen that there are not significant difference between the proportions of death/no death event patients with or without Diabetes. Likewise, there are not visible difference between the percentage of dead patients in woman and man groups, hence, sex would not be a significant variable to predict heart failure. Another variable with a similar behaviour is smoking, where no evident difference between smokers and no smokers can be settle due to the dead rates are almost the same in both groups.
#
# Conversely, a difference can be observed in anaemia condition, because patients who have this disorder have also a higher rate of dead event than healthy ones. Additionally, regarding high blood pressure variable, it is shown that patients with this condition have also the largest rates of dead events than those who do not have it.
# Hence, Anaemia and High Blood Pressure are the only two categorical variable that are going to be considered in order to predict heart failure.

# %% [markdown]
# ### Pearson correlations

# %%
plt.figure(figsize=(6,5))
sns.heatmap(data[continuous_variables].corr(), annot = True, cmap = 'coolwarm');

# %% [markdown]
# The heatmap above illustrates the Pearson correlation coefficient between each continuous variable. There are no high linear correlations observed. The highest coefficient is -0.22 between time and age variables, still it is very low considering that the minimum and maximum absolute values are 0 and 1.
#
# ### Target: Death events

# %%
plt.rcParams['figure.facecolor'] = 'white'
labels = ['No death events','Death events']
plt.pie(data['DEATH_EVENT'].value_counts(normalize=True), autopct='%1.1f%%', shadow=True, startangle=90);
plt.legend(labels)
plt.title('Death events proportion')
plt.show();

# %%
data['DEATH_EVENT'].value_counts(normalize=True)
# Out:
# 0    0.67893
# 1    0.32107
# Name: DEATH_EVENT, dtype: float64

# %% [markdown]
# The figure gives information about the proportion of the target variable in the dataset. To be specific, it illustrates that the dataset is unbalanced, with 32% dead event and 67% no dead event.

# %% [markdown]
# ## Machine Learning approach
# ## Feature selection
# ### Select KBest
#
# Select KBest method scores the variables based on chi2, f-classif, f-regression, mutual info classif stats and selects the best ones to predict the heart failure. However, it is necessary to apply this test for continuous and categorical data separately, because Chi2 test is suitable only for categorical data. Regarding continuous data, f_classif score function can be applied.
# #### Continuous variables

# %%
from sklearn.feature_selection import SelectKBest, chi2, f_classif

# %%
y = data.DEATH_EVENT
cont_selector = SelectKBest(f_classif, k=2) 
#The value of k is arbitrary, in this case Select KBest is used to get scores, not an specific number of features.
cont_selector.fit(data[continuous_variables], y)

cont_ranks = pd.DataFrame(dict(zip(continuous_variables, cont_selector.scores_)), index=['Scores']).T
cont_ranks['Support'] = cont_selector.get_support()
cont_ranks.sort_values('Scores', ascending=False, inplace=True)
cont_ranks
# Out:
#                               Scores  Support
# time                      114.181264     True
# serum_creatinine           28.158492     True
# ejection_fraction          23.094063    False
# age                        20.435946    False
# serum_sodium               11.765331    False
# creatinine_phosphokinase    1.173259    False
# platelets                   0.718880    False

# %% [markdown]
# #### Categorical variables

# %%
cat_selector = SelectKBest(f_classif, k=2) 
#The value of k is arbitrary, in this case Select KBest is used to get scores, not an specific number of features.
cat_selector.fit(data[binary_variables], y)

cat_ranks = pd.DataFrame(dict(zip(binary_variables, cat_selector.scores_)), index=['Scores']).T
cat_ranks['Support'] = cat_selector.get_support()
cat_ranks.sort_values('Scores', ascending=False, inplace=True)
cat_ranks
# Out:
#                        Scores  Support
# high_blood_pressure  1.881937     True
# anaemia              1.310096     True
# smoking              0.047333    False
# sex                  0.005534    False
# diabetes             0.001121    False

# %% [markdown]
# On the one hand, it is undoubtedly clear that in categorical variables only **High blood pressure** and **Anaemia** can be useful to predict heart failure.
#
# On the other hand, the continuous variables with the highest scores are **Time**, **Serum Creatinine**, **Ejection Fraction**, **Age** and **Serum sodium**. Notably, this results agree with what was previously obtained in the Exploratory analysis.

# %%
candidate_variables = cont_ranks.index.tolist()[:5] + cat_ranks.index.tolist()[:2]
candidate_variables
# Out:
# ['time',
#  'serum_creatinine',
#  'ejection_fraction',
#  'age',
#  'serum_sodium',
#  'high_blood_pressure',
#  'anaemia']

# %% [markdown]
# ### Models
#
# Different classifiers are trained in order to select the one that best predicts the target variable "Heart Failure". To begin with, the data is split in 80% to train the model and 20% to test it. Cross validation is applied in training phase to avoid overfitting.

# %%
from sklearn.model_selection import train_test_split

# %%
X = data[candidate_variables]
y = data.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2021)

# %% [markdown]
# #### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.feature_selection import RFECV
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, roc_curve, classification_report, plot_roc_curve, plot_confusion_matrix

# %% [markdown]
# The hyperparameters of the Decision Tree are found using Grid Search cross validation, put in other words, models are trained using the parameters' combination given in "params" variable, and the best params are those that maximize the scoring method ("scoring"), for instance, Balanced Accuracy, ROC_AUC score and f1 score.
#
# In this case, the data is imbalanced, therefore, the scoring method balanced accuracy and f1 micro are more suitable than ROC Area under curve. However, the parameter "class weight" can be used to give more weight to the minority class (1: Death event) and then use ROC_AUC scoring method, or another one for balanced data.
#
# ##### DTC ROC_AUC 1

# %%
# %%time
dtc = DecisionTreeClassifier(random_state=0)
params = {'max_depth':[4,5,6,7,8,9,10], 'min_samples_split':[2,3,4,5,6], 
          'max_features':['sqrt','log2', 6, 7], 'class_weight':['balanced',None]}
dtc_cv = GridSearchCV(dtc, params, scoring='roc_auc', cv=10).fit(X_train, y_train)

#TRAIN
print(dtc_cv.best_params_)
print(20*'=','TRAINING METRICS',20*'=')
dtc_cv = dtc_cv.best_estimator_
y_pred = dtc_cv.predict(X_train)
print(classification_report(y_train, y_pred))
print(20*'=','TESTING METRICS',20*'=')
y_pred_test = dtc_cv.predict(X_test)
print(classification_report(y_test, y_pred_test))
# Out:
# {'class_weight': None, 'max_depth': 4, 'max_features': 6, 'min_samples_split': 6}
# ==================== TRAINING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       159
#            1       0.79      0.86      0.83        80
#
#     accuracy                           0.88       239
#    macro avg       0.86      0.87      0.87       239
# weighted avg       0.88      0.88      0.88       239
#
# ==================== TESTING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.97      0.82      0.89        44
#            1       0.65      0.94      0.77        16
#
#     accuracy                           0.85        60
#    macro avg       0.81      0.88      0.83        60
# weighted avg       0.89      0.85      0.86        60
#
# CPU times: user 13.1 s, sys: 27.1 ms, total: 13.1 s
# Wall time: 13.1 s

# %% [markdown]
# There is a difference between the metrics of each class (0: No death event; 1: Death event). Naturally, f1-score is higher for the majority class, however, the difference between the metrics in training set and testing set is bigger for the minority class. This is, 83% f1-score (the harmonic mean of recall and precision) in training set, and only 77% in testing set. For this reason, another combinations of hyperparameters are tuned.
#
# ##### DTC ROC_AUC 2

# %%
# %%time
dtc = DecisionTreeClassifier(random_state=0)
params = {'max_depth':[3,4,5,6,7,8,9,10], 'min_samples_split':[2,3,4,5,6,7,8,9], 
          'max_features':['sqrt','log2', 6, 7], 'class_weight':['balanced',None]}
dtc_cv = GridSearchCV(dtc, params, scoring='roc_auc', cv=10).fit(X_train, y_train)

print(dtc_cv.best_params_)
print(20*'=','TRAINING METRICS',20*'=')
dtc_cv = dtc_cv.best_estimator_
y_pred = dtc_cv.predict(X_train)
print(classification_report(y_train, y_pred))
print(20*'=','TESTING METRICS',20*'=')
y_pred_test = dtc_cv.predict(X_test)
print(classification_report(y_test, y_pred_test))
# Out:
# {'class_weight': None, 'max_depth': 3, 'max_features': 7, 'min_samples_split': 9}
# ==================== TRAINING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91       159
#            1       0.80      0.82      0.81        80
#
#     accuracy                           0.87       239
#    macro avg       0.86      0.86      0.86       239
# weighted avg       0.88      0.87      0.87       239
#
# ==================== TESTING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90        44
#            1       0.68      0.94      0.79        16
#
#     accuracy                           0.87        60
#    macro avg       0.83      0.89      0.85        60
# weighted avg       0.90      0.87      0.87        60
#
# CPU times: user 24 s, sys: 48.8 ms, total: 24 s
# Wall time: 24 s

# %% [markdown]
# It can be clearly seen that the metrics of both classes with this Decision Tree model do not present a big gap between training ans testing, hence, this model seems to be useful to predict new cases of heart failure.
#
# In this case it is important to privilege recall over precision, certainly, this consideration applies in large amount of healthcare modelling. In regard to this, False Negative cases are more dangerous than False Positive ones, because in the first case a person could receive a diagnosis of "No death event" when actually the person is going to have a heart failure and that is worse than to give a diagnosis of death event when is it not going to happen. That is the approach of this case, nevertheless, this decision about what is worse depends on the problem and how the model is going to be used, therefore, it could be different according to those factors and the application's particularities.

# %%
plt.figure(figsize=(5,4))
plt.style.use('classic')
sns.heatmap(confusion_matrix(y_test, y_pred_test), annot=True, yticklabels=['No death event','Death event'], xticklabels=['No death event','Death event'])
plt.xlabel('Predicted label')
plt.ylabel('True label');
plt.title('Confusion Matrix DTC ROC_AUC 2');

# %% [markdown]
# * 37 cases are predicted correctly as No death events
# * 15 cases are predicted correctly as Death events
# * 7 cases are predicted wrongly as Death event when it is not going to happen (False Positive).
# * 1 case is predicted wrongly as No death event when a heart failure is going to take place (False Negative).

# %%
plt.figure(figsize=(20,6))
tree.plot_tree(dtc_cv, filled=True, rounded=True, feature_names=X_train.columns.tolist(), proportion=True);

# %% [markdown]
# Notably, this Decision Tree includes in the first levels the variables **Time**, **Serum creatinine** and **Ejection fraction**, that where the three top variables selected previously through Select KBest (f test) .
#
# The nodes with gini = 0 have perfect separation between both classes. It means, the less gini the better the classification, because node's gini coefficient indicates the dispersion inside of it. Thus, a weighted gini is calculated using the samples' percentage of each node as its weight.

# %%
print('Weighted gini: {:.2f}'.format(0.278*2.5 + 0.069*11.7 + 0.351*9.2 + 0.432*7.9 + 0.104*53.1 + 0.453* 10.9 + 0.219*3.3))
# Out:
# Weighted gini: 19.33

# %%
pd.DataFrame(zip(X_train.columns, dtc_cv.feature_importances_), columns=['Feature','Importance']).sort_values('Importance', ascending=False)
# Out:
#                Feature  Importance
# 0                 time    0.696992
# 1     serum_creatinine    0.204476
# 2    ejection_fraction    0.083504
# 4         serum_sodium    0.015028
# 3                  age    0.000000
# 5  high_blood_pressure    0.000000
# 6              anaemia    0.000000

# %% [markdown]
# Remarkably, only 4 variables are used in this model and one feature concentrates almost 70% of the total importance. Ideally, the importance would be more distributed. Another models were trained to explore more options.

# %% [markdown]
# ##### DTC Balanced Accuracy

# %%
# %%time
dtc = DecisionTreeClassifier(random_state=0)
params = {'max_depth':[3,4,5,6,7,8,9,10], 'min_samples_split':[2,3,4,5,6,7,8,9], 
          'max_features':['log2',6,7], 'class_weight':['balanced',{0:44,1:56}, {0:45,1:55}, {0:43,1:57}]}
dtc_cv = GridSearchCV(dtc, params, scoring='balanced_accuracy', cv=10).fit(X_train, y_train)

print(dtc_cv.best_params_)
print(20*'=','TRAINING METRICS',20*'=')
dtc_cv = dtc_cv.best_estimator_
y_pred = dtc_cv.predict(X_train)
print(classification_report(y_train, y_pred))
print(20*'=','TESTING METRICS',20*'=')
y_pred_test = dtc_cv.predict(X_test)
print(classification_report(y_test, y_pred_test))
# Out:
# {'class_weight': 'balanced', 'max_depth': 3, 'max_features': 7, 'min_samples_split': 8}
# ==================== TRAINING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       159
#            1       0.79      0.82      0.80        80
#
#     accuracy                           0.87       239
#    macro avg       0.85      0.86      0.85       239
# weighted avg       0.87      0.87      0.87       239
#
# ==================== TESTING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90        44
#            1       0.68      0.94      0.79        16
#
#     accuracy                           0.87        60
#    macro avg       0.83      0.89      0.85        60
# weighted avg       0.90      0.87      0.87        60
#
# CPU times: user 31.8 s, sys: 61.5 ms, total: 31.9 s
# Wall time: 31.9 s

# %%
plt.figure(figsize=(20,6))
tree.plot_tree(dtc_cv, filled=True, rounded=True, feature_names=X_train.columns.tolist(), proportion=True);

# %%
print('Weighted gini: {:.2f}'.format(0.101*12.6 + 0.329*11.7 + 0.466*7.9 + 0.129*53.1 + 0.415*10.9 + 0.26*3.3))
# Out:
# Weighted gini: 21.03

# %% [markdown]
# Even when the metrics for the test set are the same as the obtained ones with DTC ROC_AUC 2, this Decision Tree has a higher Weighted gini.

# %% [markdown]
# #### Random Forest Classifier
# ##### RFC recall_micro

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# %%time
rfc = RandomForestClassifier(random_state=0)
params = {'n_estimators':[43,44,45,46,47],
          'max_depth':[3,4,5,6,7], 
          'min_samples_split':[2,3,4,5,6,7,8,9,10], 
          'max_features':['sqrt','log2'], 
          'class_weight':['balanced',None,'balanced_subsample']}
rfc_cv = GridSearchCV(rfc, params, n_jobs=-1, scoring='recall_micro', cv=10).fit(X_train, y_train)

print(rfc_cv.best_params_)
print(20*'=','TRAINING METRICS',20*'=')
rfc_cv = rfc_cv.best_estimator_
y_pred = rfc_cv.predict(X_train)
print(classification_report(y_train, y_pred))
print(20*'=','TESTING METRICS',20*'=')
y_pred_test = rfc_cv.predict(X_test)
print(classification_report(y_test, y_pred_test))
# Out:
# {'class_weight': 'balanced', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_split': 6, 'n_estimators': 44}
# ==================== TRAINING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       159
#            1       0.88      0.95      0.92        80
#
#     accuracy                           0.94       239
#    macro avg       0.93      0.94      0.94       239
# weighted avg       0.94      0.94      0.94       239
#
# ==================== TESTING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        44
#            1       0.88      0.88      0.88        16
#
#     accuracy                           0.93        60
#    macro avg       0.91      0.91      0.91        60
# weighted avg       0.93      0.93      0.93        60
#
# CPU times: user 43.8 s, sys: 1.62 s, total: 45.4 s
# Wall time: 2min 2s

# %%
plt.figure(figsize=(5,4))
plt.style.use('classic')
sns.heatmap(confusion_matrix(y_test, y_pred_test), annot=True, yticklabels=['No death event','Death event'], xticklabels=['No death event','Death event'])
plt.xlabel('Predicted label')
plt.ylabel('True label');
plt.title('Confusion Matrix RFC RECALL_MICRO');

# %%
pd.DataFrame(zip(X_train.columns, rfc_cv.feature_importances_), columns=['Feature','Importance']).sort_values('Importance', ascending=False)
# Out:
#                Feature  Importance
# 0                 time    0.404599
# 1     serum_creatinine    0.196797
# 2    ejection_fraction    0.145162
# 3                  age    0.123660
# 4         serum_sodium    0.100690
# 6              anaemia    0.016455
# 5  high_blood_pressure    0.012637

# %% [markdown]
# In this case, it can be clearly seen an improvement not only in the training metrics, also in the test set. This is, a 95% precision and recall for No death event data, whereas Death event data reach 88% in the same metrics. Thus, an Accuracy of 93% overall can be observed.
#
# Regarding the number of features, conversely than in DTC ROC_UC 2, in RFC recall_micro all variables are important in this model, and the importances are more distributed.

# %% [markdown]
# ##### RFC ROC_AUC

# %%
# %%time
rfc = RandomForestClassifier(random_state=0)
params = {'n_estimators':[40,50,60,70,80,90,100,110],
          'max_depth':[3,4,5,6,7,8,9], 
          'min_samples_split':[2,3,4,5,6,7,8,9,10], 
          'max_features':['sqrt','log2',6,7], 
          'class_weight':['balanced_subsample', None, 'balanced']}
rfc_cv = GridSearchCV(rfc, params, n_jobs=-1, scoring='roc_auc', cv=10).fit(X_train, y_train)

print(rfc_cv.best_params_)
print(20*'=','TRAINING METRICS',20*'=')
rfc_cv = rfc_cv.best_estimator_
y_pred = rfc_cv.predict(X_train)
print(classification_report(y_train, y_pred))
print(20*'=','TESTING METRICS',20*'=')
y_pred_test = rfc_cv.predict(X_test)
print(classification_report(y_test, y_pred_test))
# Out:
# {'class_weight': 'balanced_subsample', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}
# ==================== TRAINING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       159
#            1       1.00      1.00      1.00        80
#
#     accuracy                           1.00       239
#    macro avg       1.00      1.00      1.00       239
# weighted avg       1.00      1.00      1.00       239
#
# ==================== TESTING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        44
#            1       0.88      0.88      0.88        16
#
#     accuracy                           0.93        60
#    macro avg       0.91      0.91      0.91        60
# weighted avg       0.93      0.93      0.93        60
#
# CPU times: user 3min 41s, sys: 7.45 s, total: 3min 48s
# ...

# %% [markdown]
# The metrics in this case are perfect (100%) for the training set, however, in testing set the metrics are not better than in RFC recall_micro. This is a case of overfitting, due to 100% is reached in training set, nevertheless, it is a considerable gap with the metrics of test set.

# %% [markdown]
# ##### RFC f1_micro

# %%
# %%time
rfc = RandomForestClassifier(random_state=0)
params = {'n_estimators':[40,50,60,70,80,90,100],
          'max_depth':[3,4,5,6,7,8,9,10], 
          'min_samples_split':[2,3,4,5,6,7,8,9,10], 
          'max_features':['sqrt','log2',6,7], 
          'class_weight':['balanced',None,'balanced_subsample']}
rfc_cv = GridSearchCV(rfc, params, n_jobs=-1, scoring='f1_micro', cv=10).fit(X_train, y_train)

print(rfc_cv.best_params_)
print(20*'=','TRAINING METRICS',20*'=')
rfc_cv = rfc_cv.best_estimator_
y_pred = rfc_cv.predict(X_train)
print(classification_report(y_train, y_pred))
print(20*'=','TESTING METRICS',20*'=')
y_pred_test = rfc_cv.predict(X_test)
print(classification_report(y_test, y_pred_test))
# Out:
# {'class_weight': 'balanced', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_split': 8, 'n_estimators': 50}
# ==================== TRAINING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96       159
#            1       0.89      0.96      0.92        80
#
#     accuracy                           0.95       239
#    macro avg       0.93      0.95      0.94       239
# weighted avg       0.95      0.95      0.95       239
#
# ==================== TESTING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92        44
#            1       0.74      0.88      0.80        16
#
#     accuracy                           0.88        60
#    macro avg       0.84      0.88      0.86        60
# weighted avg       0.89      0.88      0.89        60
#
# CPU times: user 3min 54s, sys: 7.51 s, total: 4min 1s
# Wall time: 16min 33s

# %% [markdown]
# This model is worse than the previous one.

# %% [markdown]
# ### XGBoost
# #### XGBoost ROC_AUC

# %%
# check xgboost version
import xgboost
from xgboost import XGBClassifier

# %%
# %%time
xgb = XGBClassifier(eta=0.1, colsample_bytree=0.8, use_label_encoder=False)
params = {'n_estimators':[30,40,50,60,70,80,90,100],
          'max_depth':[3,4,5,6,7,8,9,10], 
          'subsample':[0.8, 0.7]}
xgb_cv = GridSearchCV(xgb, params, n_jobs=-1, scoring='roc_auc', cv=10).fit(X_train, y_train.astype('int8'))
print(xgb_cv.best_params_)
print(20*'=','TRAINING METRICS',20*'=')
xgb_cv = xgb_cv.best_estimator_
y_pred = xgb_cv.predict(X_train)
print(classification_report(y_train, y_pred))
print(20*'=','TESTING METRICS',20*'=')
y_pred_test = xgb_cv.predict(X_test)
print(classification_report(y_test, y_pred_test))
# Out:
# [19:48:27] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# {'max_depth': 9, 'n_estimators': 80, 'subsample': 0.8}
# ==================== TRAINING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       159
#            1       0.97      0.97      0.97        80
#
#     accuracy                           0.98       239
#    macro avg       0.98      0.98      0.98       239
# weighted avg       0.98      0.98      0.98       239
#
# ==================== TESTING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95        44
#            1       0.83      0.94      0.88        16
#
# ...

# %%
# %%time
xgb = XGBClassifier(eta=0.1, colsample_bytree=0.8, use_label_encoder=False)
params = {'n_estimators':[30,40,50,60,70,80,90,100],
          'max_depth':[3,4,5,6,7,8,9,10], 
          'subsample':[0.8, 0.7]}
xgb_cv = GridSearchCV(xgb, params, n_jobs=-1, scoring='f1_micro', cv=10).fit(X_train, y_train.astype('int8'))
print(xgb_cv.best_params_)
print(20*'=','TRAINING METRICS',20*'=')
xgb_cv = xgb_cv.best_estimator_
y_pred = xgb_cv.predict(X_train)
print(classification_report(y_train, y_pred))
print(20*'=','TESTING METRICS',20*'=')
y_pred_test = xgb_cv.predict(X_test)
print(classification_report(y_test, y_pred_test))
# Out:
# [19:50:56] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# {'max_depth': 6, 'n_estimators': 40, 'subsample': 0.7}
# ==================== TRAINING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97       159
#            1       0.94      0.93      0.93        80
#
#     accuracy                           0.95       239
#    macro avg       0.95      0.95      0.95       239
# weighted avg       0.95      0.95      0.95       239
#
# ==================== TESTING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93        44
#            1       0.75      0.94      0.83        16
#
# ...

# %%
# %%time
xgb = XGBClassifier(eta=0.1, colsample_bytree=0.8, use_label_encoder=False)
params = {'n_estimators':[30,40,50,60,70,80,90,100],
          'max_depth':[3,4,5,6,7,8,9,10], 
          'subsample':[0.8, 0.7]}
xgb_cv = GridSearchCV(xgb, params, n_jobs=-1, scoring='balanced_accuracy', cv=10).fit(X_train, y_train.astype('int8'))
print(xgb_cv.best_params_)
print(20*'=','TRAINING METRICS',20*'=')
xgb_cv = xgb_cv.best_estimator_
y_pred = xgb_cv.predict(X_train)
print(classification_report(y_train, y_pred))
print(20*'=','TESTING METRICS',20*'=')
y_pred_test = xgb_cv.predict(X_test)
print(classification_report(y_test, y_pred_test))
# Out:
# [19:53:26] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# {'max_depth': 4, 'n_estimators': 90, 'subsample': 0.7}
# ==================== TRAINING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       159
#            1       0.97      0.96      0.97        80
#
#     accuracy                           0.98       239
#    macro avg       0.98      0.97      0.98       239
# weighted avg       0.98      0.98      0.98       239
#
# ==================== TESTING METRICS ====================
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95        44
#            1       0.83      0.94      0.88        16
#
# ...

# %%
plt.figure(figsize=(5,4))
plt.style.use('classic')
sns.heatmap(confusion_matrix(y_test, y_pred_test), annot=True, yticklabels=['No death event','Death event'], xticklabels=['No death event','Death event'])
plt.xlabel('Predicted label')
plt.ylabel('True label');
plt.title('Confusion Matrix XGB BALANCED_ACCURACY');

# %%
pd.DataFrame(dict(zip(X.columns, xgb_cv.feature_importances_)), index=[0]).T.rename(columns={0:'Importance'}).sort_values('Importance', ascending=False)
# Out:
#                      Importance
# time                   0.291493
# serum_creatinine       0.184257
# ejection_fraction      0.153545
# age                    0.114534
# serum_sodium           0.112821
# anaemia                0.078037
# high_blood_pressure    0.065314

# %% [markdown]
# This model is better than the first xgboost, because even when the testing metrics are the same in both models, the first one has a bigger gap between the training and testing metrics than this model and the lower the gap, the lower over fitting.

# %% [markdown]
# ## CONCLUSIONS
# To summarize, it can be clearly seen in the figure bellow that using confusion matrix, recall and precision metrics, the best models are the **RFC RECALL_MICRO** and the **XGB BALANCED_ACCURACY**.

# %% [markdown]
# ![](images/cf_DTC.PNG)
# ![](images/cf_DTC.png)
# <img src="images/cf_DTC.png" />
# <img src="images/cf_DTC.PNG" />

# %% [markdown]
# Accordingly, both models have the same number of false predictions, nonetheless, one has 2 False negative and 2 False positive, whereas the other one has only 1 False negative and 3 False positives. Hence, the final decision will be vested on the cost of FP and FN.
#
# Under the assumption of FN predictions are by far worse than FP ones, because failing in a death prediction can be logically considered worse, the chosen model should be **XGB BALANCED ACCURACY**.
#
# Another aspect that has to be acknowledged is that in both models, the most important features are:
#
#
# | Feature | RFC RECALL_MICRO | XGB BALANCED_ACCURACY |
# | --- | -: | -: |
# | time | 0.404599 | 0.291493 |
# | serum_creatinine | 0.196797 | 0.184257 |
# | ejection_fraction | 0.145162 | 0.153545 |
# | age | 0.123660 | 0.114534 |
# | serum_sodium | 0.100690 | 0.112821 |
# | anaemia | 0.016455 | 0.078037 |
# | high_blood_pressure | 0.012637 | 0.065314 |
#
#
# In conclusion to be brief, based on the available data, the trained model allows predicting Heart Failure in individuals, from the features time, serum creatinine, ejection fraction, age, serum sodium, anaemia, high blood pressure. The model's accuracy reaches 93%, having 94% of sensibility for the most relevant class, which is death event. It is proposed as future work to gather more data in order to test the model in a larger number of individuals and reaffirm the applicability of the model.
